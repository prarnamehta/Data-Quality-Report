# %% [markdown]
# # Lab 1
# ## By Prarna Mehta
#
# In this excercise, we would be generating and discussing the data quality report for the dataset "Credit"

# %%
# import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Dataset 1: Credit

# %%
# Explore the dataset we are going to use for the analysis
credit_df = pd.read_csv('Credit.csv')
credit_df
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Own Student Married  \
# 0     14.891   3606     283      2   34         11   No      No     Yes
# 1    106.025   6645     483      3   82         15  Yes     Yes     Yes
# 2    104.593   7075     514      4   71         11   No      No      No
# 3    148.924   9504     681      3   36         11  Yes      No      No
# 4     55.882   4897     357      2   68         16   No      No     Yes
# ..       ...    ...     ...    ...  ...        ...  ...     ...     ...
# 395   12.096   4100     307      3   32         13   No      No     Yes
# 396   13.364   3838     296      5   65         17   No      No      No
# 397   57.872   4171     321      5   67         12  Yes      No     Yes
# 398   37.728   2525     192      1   44         13   No      No     Yes
# 399   18.701   5524     415      5   64          7  Yes      No      No
#
#     Region  Balance
# 0    South      333
# 1     West      903
# 2     West      580
# ...

# %%
# classify columns into categorical and quantitative variables

def check_variables(credit_df: pd.DataFrame):
    cols = credit_df.columns
    quantitative_cols = credit_df._get_numeric_data().columns
    categorical_cols = list(set(cols) - set(quantitative_cols))
    return categorical_cols, list(set(quantitative_cols))

cat_cols, quan_cols = check_variables(credit_df)
print(f'categorical columns: {cat_cols}')
print(f'quantitative columns: {quan_cols}')
# Out:
# categorical columns: ['Married', 'Student', 'Own', 'Region']
# quantitative columns: ['Education', 'Cards', 'Income', 'Age', 'Rating', 'Limit', 'Balance']

# %%
credit_df.describe()
# Out:
#            Income         Limit      Rating       Cards         Age  \
# count  400.000000    400.000000  400.000000  400.000000  400.000000
# mean    45.218885   4735.600000  354.940000    2.957500   55.667500
# std     35.244273   2308.198848  154.724143    1.371275   17.249807
# min     10.354000    855.000000   93.000000    1.000000   23.000000
# 25%     21.007250   3088.000000  247.250000    2.000000   41.750000
# 50%     33.115500   4622.500000  344.000000    3.000000   56.000000
# 75%     57.470750   5872.750000  437.250000    4.000000   70.000000
# max    186.634000  13913.000000  982.000000    9.000000   98.000000
#
#         Education      Balance
# count  400.000000   400.000000
# mean    13.450000   520.015000
# std      3.125207   459.758877
# min      5.000000     0.000000
# 25%     11.000000    68.750000
# 50%     14.000000   459.500000
# 75%     16.000000   863.000000
# max     20.000000  1999.000000

# %%
credit_df.describe(include = "object")
# Out:
#         Own Student Married Region
# count   400     400     400    400
# unique    2       2       2      3
# top     Yes      No     Yes  South
# freq    207     360     245    199

# %% [markdown]
# # Data Quality Report:
#
#
# #### For Continous Variables
#
# ![image-4.png](attachment:image-4.png)
#
# #### For Categorical Variables
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# ### 1. Missing Values:
# We would first like to check the missing values in the dataset

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Income     400 non-null    float64
#  1   Limit      400 non-null    int64
#  2   Rating     400 non-null    int64
#  3   Cards      400 non-null    int64
#  4   Age        400 non-null    int64
#  5   Education  400 non-null    int64
#  6   Own        400 non-null    object
#  7   Student    400 non-null    object
#  8   Married    400 non-null    object
#  9   Region     400 non-null    object
#  10  Balance    400 non-null    int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 34.5+ KB

# %%
# Checking the missing values
credit_df.isnull().sum()
# Out:
# Income       0
# Limit        0
# Rating       0
# Cards        0
# Age          0
# Education    0
# Own          0
# Student      0
# Married      0
# Region       0
# Balance      0
# dtype: int64

# %% [markdown]
# ### Comments:
#
# In this dataset, there are no missing values.

# %% [markdown]
# ### 2. Irregular Cardinality

# %%
credit_df.nunique()
# Out:
# Income       399
# Limit        387
# Rating       283
# Cards          9
# Age           68
# Education     16
# Own            2
# Student        2
# Married        2
# Region         3
# Balance      284
# dtype: int64

# %% [markdown]
# ### Comments:
#
# The cardinality is high for features income, limit, Ratings,and Balance where as the features Cards, Own, Student, Married, Region, have low cardinality.

# %% [markdown]
# ### 3. Outliers
#
# We check for outliers for quantitative features using boxplots.

# %%
# box plot for a quantitative variable (‘Cards’) from data frame
plt.boxplot(x=credit_df['Cards'], labels=['Cards'])
plt.ylabel('Cards')
# Out:
# Text(0, 0.5, 'Cards')

# %%
# box plot for a quantitative variable (‘Limit’) from data frame
plt.boxplot(x=credit_df['Limit'], labels=['Limit'])
plt.ylabel('Limit')
# Out:
# Text(0, 0.5, 'Limit')

# %%
# box plot for a quantitative variable (‘Balance’) from data frame
plt.boxplot(x=credit_df['Balance'], labels=['Balance'])
plt.ylabel('Balance')
# Out:
# Text(0, 0.5, 'Balance')

# %%
# box plot for a quantitative variable (‘Education’) from data frame
plt.boxplot(x=credit_df['Education'], labels=['Education'])
plt.ylabel('Education')
# Out:
# Text(0, 0.5, 'Education')

# %%
# box plot for a quantitative variable (‘Income’) from data frame
plt.boxplot(x=credit_df['Income'], labels=['Income'])
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %%
# box plot for a quantitative variable (‘Age’) from data frame
plt.boxplot(x=credit_df['Age'], labels=['Age'])
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
# box plot for a quantitative variable (‘Rating’) from data frame
plt.boxplot(x=credit_df['Rating'], labels=['Rating'])
plt.ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')

# %% [markdown]
# ### Comments:
#
# The features Rating, Income, limit and card have outliers.
#
# ### 4. Feature Distributions
#
# We would like to see the distribution of each features.

# %%
sns.set_style("whitegrid")
credit_df['Income'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comment:
# The distribution is skewed right, unimodal and there are few outliers.

# %%
sns.set_style("whitegrid")
credit_df['Rating'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comment:
# The distribution is skewed slightly towards the right, unimodal and there are few outliers.

# %%
sns.set_style("whitegrid")
credit_df['Cards'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comment:
# The distribution is skewed right, unimodal and there are few outliers.

# %%
sns.set_style("whitegrid")
credit_df['Limit'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comment:
# The distribution is multimodal and there are few outliers.

# %%
sns.set_style("whitegrid")
credit_df['Age'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comment:
# The distribution is more or less uniform, multimodal and there are few outliers.

# %%
sns.set_style("whitegrid")
credit_df['Education'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comment:
# The distribution is skewed left, and unimodal.

# %%
sns.set_style("whitegrid")
credit_df['Balance'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comment:
# The distribution is uniformly distributed and there are few outliers.

# %%
credit_df.groupby('Own').size().plot(kind='bar', rot=0,colormap='Paired')
# Out:
# <AxesSubplot:xlabel='Own'>

# %% [markdown]
# ### Comment:
# The categorical feature 'Own' is binary variable, with a small difference in number of samples for both categories.

# %%
credit_df.groupby('Student').size().plot(kind='bar', rot=0,colormap='Paired')
# Out:
# <AxesSubplot:xlabel='Student'>

# %% [markdown]
# ### Comment:
# The categorical feature 'Student' is binary variable, with a big difference between both categories with respect to number of samples. This suggests that we need to include more samples of students, to obtain unbiased result.

# %%
credit_df.groupby('Married').size().plot(kind='bar', rot=0,colormap='Paired')
# Out:
# <AxesSubplot:xlabel='Married'>

# %% [markdown]
# ### Comment:
# The categorical feature 'Married' is binary variable, with a difference in number of samples for both categories. This suggests that we have to include more samples of single profiles.

# %%
credit_df.groupby('Region').size().plot(kind='bar', rot=0,colormap='Paired')
# Out:
# <AxesSubplot:xlabel='Region'>

# %% [markdown]
# ### Comment:
# The categorical feature 'Region' has three categories, suggesting that the sample has more instance of the region 'South'. We need to include more samples for region East and West to obtain unbiased results.

# %% [markdown]
# ### 5. Relationship between descriptive features and target feature
#
# #### We first explore the relationship between continous features an target features

# %%
credit_df.plot.scatter(x="Income",y="Balance") 
plt.show()

credit_df.plot.scatter(x="Age",y="Balance") 
plt.show()

credit_df.plot.scatter(x="Cards",y="Balance") 
plt.show()

credit_df.plot.scatter(x="Education",y="Balance") 
plt.show()

credit_df.plot.scatter(x="Limit",y="Balance") 
plt.show()

credit_df.plot.scatter(x="Rating",y="Balance") 
plt.show()

# %% [markdown]
# ### Comment:
#
# From the above Scatterplots, we can observe that,
# - Income vs Balance
# As the income increases, the balance increases, hence there is a positve relationship
# - Age vs Balance
# There is no relationship between age and balance. The cardinality of this feature is 68, which requires some adjustments.
# - Cards vs Balance
# There is no relationship between Cards and balance. The cardinality of this feature is 9, which requires some adjustments.
# - Education vs Balance
# There is no relationship between Education and balance. The cardinality of this feature is 16, which requires some adjustments.
# - Limit vs Balance
# There is a positive relatonship, that is as the limit increases, the balance also increases.
# - Rating vs Balance
# There is postive relationship, that is as the rating increases, the balance also increases.
#
# #### Next, we explore the relationship between categorical features and target variable

# %%
#plt.figure(figsize=(8,10))
sns.boxplot(x="Own", y="Balance", data=credit_df)
# Out:
# <AxesSubplot:xlabel='Own', ylabel='Balance'>

# %% [markdown]
# ### Comment:
#
# With respect to balance, the distribution of categorical feature 'Own' is right skewed, most of the samples in both the categories have balance around 500.

# %%
sns.boxplot(x="Married", y="Balance", data=credit_df)
# Out:
# <AxesSubplot:xlabel='Married', ylabel='Balance'>

# %% [markdown]
# ### Comment:
#
# With respect to balance, the distribution of categorical feature 'Married' is right skewed, most of the samples in both the categories have balance around 500.

# %%
sns.boxplot(x="Student", y="Balance", data=credit_df)
# Out:
# <AxesSubplot:xlabel='Student', ylabel='Balance'>

# %% [markdown]
# ### Comment:
#
# With respect to balance, the distribution of samples who are not a student is right skewed with balance below 500 where as for the students it is left skewed with balance around 1000. Hence, according to the given sample, students have more balance than the non-students.

# %%
sns.boxplot(x="Region", y="Balance", data=credit_df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Balance'>

# %% [markdown]
# ### Comment:
#
# With respect to balance, the distribution of categorical feature 'Region' is right skewed, most of the samples in all the categories have balance around 500.

# %% [markdown]
# ### 6. Collinearity among continuous features

# %%
sns.heatmap(credit_df.corr(), annot=True, cmap = 'Reds') 
plt.show()

# %% [markdown]
# ### Comment:
#
# From the correlation matrix we can observe postive correlation between limit, rating with balance. We also observe a postive correlation between limit, rating with income.
#
# ### 7. Data quality plan with potential handling strategies
#
# ![image.png](attachment:image.png)
#
# # Dataset 2: Auto

# %%
# Explore the dataset we are going to use for the analysis
auto_df = pd.read_csv('Auto.csv')
auto_df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %% [markdown]
# ### Comment:
#
# We observe that horsepower data type is 'Object' but the data shows numerical values, this feature requires further investigation.

# %%
auto_df['horsepower']= auto_df['horsepower'].str.replace('?',"0").astype(int)
# Out:
# /var/folders/_3/431kwkl94nzbhgth7j74ljc40000gn/T/ipykernel_40932/244657046.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   auto_df['horsepower']= auto_df['horsepower'].str.replace('?',"0").astype(int)

# %% [markdown]
# ### Comment:
#
# The feature 'horsepower' has 5 special character '?' which indicates missing value. The special character first has to be replaced by 0 and then we can use missing value handling techniques.

# %%
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    int64
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 28.0+ KB

# %%
# classify columns into categorical and quantitative variables

def check_variables(credit_df: pd.DataFrame):
    cols = auto_df.columns
    quantitative_cols = auto_df._get_numeric_data().columns
    categorical_cols = list(set(cols) - set(quantitative_cols))
    return categorical_cols, list(set(quantitative_cols))

cat_cols, quan_cols = check_variables(credit_df)
print(f'categorical columns: {cat_cols}')
print(f'quantitative columns: {quan_cols}')
# Out:
# categorical columns: ['name']
# quantitative columns: ['origin', 'weight', 'horsepower', 'year', 'acceleration', 'cylinders', 'displacement', 'mpg']

# %%
auto_df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  397.000000  397.000000    397.000000  397.000000   397.000000
# mean    23.515869    5.458438    193.532746  103.153652  2970.261965
# std      7.825804    1.701577    104.379583   39.986602   847.904119
# min      9.000000    3.000000     68.000000    0.000000  1613.000000
# 25%     17.500000    4.000000    104.000000   75.000000  2223.000000
# 50%     23.000000    4.000000    146.000000   92.000000  2800.000000
# 75%     29.000000    8.000000    262.000000  125.000000  3609.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    397.000000  397.000000  397.000000
# mean      15.555668   75.994962    1.574307
# std        2.749995    3.690005    0.802549
# min        8.000000   70.000000    1.000000
# 25%       13.800000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
auto_df.describe(include = "object")
# Out:
#               name
# count          397
# unique         304
# top     ford pinto
# freq             6

# %% [markdown]
# # Data Quality Report
#
# ### For Continous Features
#
# ![image-5.png](attachment:image-5.png)
#
# ### For Categorical Features
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ### 1. Missing Values:
# We would first like to check the missing values in the dataset

# %%
# Checking the missing values
auto_df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# ### Comment:
#
# There are no missing values in the dataset.

# %% [markdown]
# ### 2. Irregular cardinality

# %%
auto_df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       94
# weight          350
# acceleration     95
# year             13
# origin            3
# name            304
# dtype: int64

# %% [markdown]
# ### Comments:
#
# All the features have high cardinality, except for origin, cylinders. However, high cardicality is observed in other features.

# %% [markdown]
# ### 3. Outliers

# %%
plt.boxplot(x=auto_df['origin'], labels=['origin'])
plt.ylabel('origin')
# Out:
# Text(0, 0.5, 'origin')

# %%
plt.boxplot(x=auto_df['weight'], labels=['weight'])
plt.ylabel('weight')
# Out:
# Text(0, 0.5, 'weight')

# %%
plt.boxplot(x=auto_df['year'], labels=['year'])
plt.ylabel('year')
# Out:
# Text(0, 0.5, 'year')

# %%
plt.boxplot(x=auto_df['acceleration'], labels=['acceleration'])
plt.ylabel('acceleration')
plt.show()

# %%
plt.boxplot(x=auto_df['cylinders'], labels=['cylinders'])
plt.ylabel('cylinders')
# Out:
# Text(0, 0.5, 'cylinders')

# %%
plt.boxplot(x=auto_df['displacement'], labels=['displacement'])
plt.ylabel('displacement')
# Out:
# Text(0, 0.5, 'displacement')

# %%
plt.boxplot(x=auto_df['horsepower'], labels=['horsepower'])
plt.ylabel('horsepower')
# Out:
# Text(0, 0.5, 'horsepower')

# %%
plt.boxplot(x=auto_df['mpg'], labels=['mpg'])
plt.ylabel('mpg')
# Out:
# Text(0, 0.5, 'mpg')

# %% [markdown]
# ### Comment:
#
# Outliers are observed for features 'acceleration', 'horsepower' and the target feature 'mpg'

# %% [markdown]
# ### 4. Feature Distributions

# %%
sns.set_style("whitegrid")
auto_df['origin'].hist(bins=3)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comment:
# The distribution is right-skewed, and unimodal.

# %%
sns.set_style("whitegrid")
auto_df['weight'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comment:
#
# The distribution is right skewed, and multimodal.

# %%
sns.set_style("whitegrid")
auto_df['year'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comment
# The distribution is uniformly distributed.

# %%
sns.set_style("whitegrid")
auto_df['acceleration'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comments:
# the distribution is uniformly distributed, multimoal, and there are outliers.

# %%
sns.set_style("whitegrid")
auto_df['cylinders'].hist(bins=5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comments:
#
# The distribution has most of the sample instances for values around 4

# %%
sns.set_style("whitegrid")
auto_df['displacement'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comments:
# the distribution is right skewed, multimodal and there are outliers.

# %%
sns.set_style("whitegrid")
auto_df['horsepower'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comments:
#
# The distribution is right skewed, multimodal and there are outliers.

# %%
sns.set_style("whitegrid")
auto_df['mpg'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Comment:
#
# the distribution is right skewed, multimodal and have outliers.

# %%
auto_df.groupby('name').size().plot(kind='bar', rot=0,colormap='Paired')
# Out:
# <AxesSubplot:xlabel='name'>

# %% [markdown]
# ### Comment:
# The distribution has 305 distinct values, hence a histogram will make no sense.
#
# ### 5. Relationship between descriptive features and target feature
#
# #### We first explore the relationship between continous features an target features

# %%
auto_df.plot.scatter(x="origin",y="mpg") 
plt.show()

auto_df.plot.scatter(x="weight",y="mpg") 
plt.show()

auto_df.plot.scatter(x="year",y="mpg") 
plt.show()

auto_df.plot.scatter(x="acceleration",y="mpg") 
plt.show()

auto_df.plot.scatter(x="cylinders",y="mpg") 
plt.show()

auto_df.plot.scatter(x="displacement",y="mpg") 
plt.show()

auto_df.plot.scatter(x="horsepower",y="mpg") 
plt.show()

# %% [markdown]
# ### Comments:
#
# From the scatterplots, we can observe that:
# - Origin vs mpg
# Due to low cardinality, the scatterplot does not provide much information.
# - weight vs mpg
# There is negative relationship, that is as the weight increases, the mpg decreases.
# - Year vs mpg
# Due to low cardinality, the scatterplot does not provide much information.
# - acceleration vs mpg
# There is positve relationship, that is as acceleration increases, mpg also increases.
# - cylinders vs mpg
# Due to low cardinality, the scatterplot does not provide much information.
# - displacment vs mpg
# There is negative relationship, that is as the displacement increases, the mpg decreases.
# - horsepower vs mpg
# There is negative relationship, that is as the horsepower increases, the mpg decreases.
# #### We now explore the relationship between the categorical fatures and target variable

# %%
plt.figure(figsize=(8,10))
sns.boxplot(x="name", y="mpg", data=auto_df)
plt.show()

# %% [markdown]
# ### Comment:
# The distribution has 305 distinct values, that is high cardinality, hence boxplots will make no sense.

# %% [markdown]
# ### 6. Collinearity among continuous features

# %%
sns.heatmap(auto_df.corr(), annot=True, cmap = 'Reds') 
plt.show()

# %% [markdown]
# ### Comment:
#
# We can observe positive correlations between
# - displacement, horsepower, weight with cylinders
#
# We can observe negative relationship between
# - displacement, horsepower, weight, cylinders with mpg
#
# ### 7. Data quality plan with potential handling strategies
#
# ![image-3.png](attachment:image-3.png)
